# %% [markdown]
# # Dataset Spark coding

# %% [markdown]
# ## Connecting to a server

# %%
# Closing all active Kerberos connections (tickets):
# (effectively logging out from Kerberos-secured services)
#!kdestroy

# Starting a Kerberos connection:
#path = "Login/"
#!kinit -kt f"{path}/Jakub.Cajzl.keytab" Jakub.Cajzl

# Displaying current login:
# !klist
# Out:
# Current LogonId is 0:0x133b8d
#
# Cached Tickets: (1)
#
# #0>	Client: Jakub.Cajzl @ ADASTRACORP.NET
# 	Server: krbtgt/ADASTRACORP.NET @ ADASTRACORP.NET
# 	KerbTicket Encryption Type: AES-256-CTS-HMAC-SHA1-96
# 	Ticket Flags 0x40e10000 -> forwardable renewable initial pre_authent name_canonicalize
# 	Start Time: 6/11/2024 12:01:23 (local)
# 	End Time:   6/11/2024 22:01:23 (local)
# 	Renew Time: 6/18/2024 12:01:23 (local)
# 	Session Key Type: AES-256-CTS-HMAC-SHA1-96
# 	Cache Flags: 0x1 -> PRIMARY
# 	Kdc Called: czprgprdw05-new.adastracorp.net

# %% [markdown]
# ## Libraries

# %%
# Importing libraries:
import sys
import pyspark
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession, DataFrame, functions, types, SQLContext

from pyspark.sql.functions import *
from pyspark.sql.types import *

from datetime import datetime, date
import pandas as pd

# It is better to load pySpark version of Pandas as 'ps' instead of 'pd'
# because pySpark has differences in their version of Pandas 
# (mainly because pySpark is masivelly parallelized and has many 
# parallelization parameters).
from pyspark import pandas as ps

import findspark
findspark.init()
# Out:
# c:\Users\Jakub.Cajzl\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyspark\pandas\__init__.py:50: UserWarning: 'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.
#   warnings.warn(

# %%
# Starting a Spark session:
spark = SparkSession.builder.appName("code01").getOrCreate()

# Spark Context:
# sc = spark.SparkContext
# sqlContext = SQLContext(sc)

# %% [markdown]
# ## Basics

# %% [markdown]
# ### DataFrame creation

# %% [markdown]
# #### 1. From list of rows

# %%
data = [
    (1, "Alice", 29),
    (2, "Bob", 31),
    (3, "Cathy", 25),
    (4, "David", 35),
    (5, "Eva", 28)
]

columns = ["id", "name", "age"]

df = spark.createDataFrame(data,columns)

# %%
df.printSchema()
# Out:
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)

# %%
print(df)
# Out:
# DataFrame[id: bigint, name: string, age: bigint]

# %%
df.count()
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File c:\Users\Jakub.Cajzl\AppData\Local\Programs\Python\Python312\Lib\site-packages\py4j\clientserver.py:503, in ClientServerConnection.send_command(self, command)
#     502 try:
# --> 503     self.socket.sendall(command.encode("utf-8"))
#     504 except Exception as e:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# Py4JNetworkError                          Traceback (most recent call last)
# File c:\Users\Jakub.Cajzl\AppData\Local\Programs\Python\Python312\Lib\site-packages\py4j\java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#
# ...

# %% [markdown]
# #### 2. With an explicit schema

# %%
df = spark.createDataFrame([
    (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
    (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
    (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
], schema='a long, b double, c string, d date, e timestamp')

df.show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[7], line 6
#       1 df = spark.createDataFrame([
#       2     (1, 2., 'string1', date(2000, 1, 1), datetime(2000, 1, 1, 12, 0)),
#       3     (2, 3., 'string2', date(2000, 2, 1), datetime(2000, 1, 2, 12, 0)),
#       4     (3, 4., 'string3', date(2000, 3, 1), datetime(2000, 1, 3, 12, 0))
#       5 ], schema='a long, b double, c string, d date, e timestamp')
# ----> 6 df.show()
#
# File c:\Users\Jakub.Cajzl\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyspark\sql\dataframe.py:945, in DataFrame.show(self, n, truncate, vertical)
#     885 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     886     """Prints the first ``n`` rows to the console.
#     887
#     888     .. versionadded:: 1.3.0
#    (...)
#     943     name | Bob
#     944     """
# ...

# %% [markdown]
# #### 3. From a pandas DataFrame

# %%
pandas_df = pd.DataFrame({
    'a': [1, 2, 3],
    'b': [2., 3., 4.],
    'c': ['string1', 'string2', 'string3'],
    'd': [date(2000, 1, 1), date(2000, 2, 1), date(2000, 3, 1)],
    'e': [datetime(2000, 1, 1, 12, 0), datetime(2000, 1, 2, 12, 0), datetime(2000, 1, 3, 12, 0)]
})
df = spark.createDataFrame(pandas_df)
df
# Out:
# DataFrame[a: bigint, b: double, c: string, d: date, e: timestamp]

# %% [markdown]
# #### Showing DataFrame and schema

# %%
# All DataFrames above result the same:
df.printSchema()
# Out:
# root
#  |-- a: long (nullable = true)
#  |-- b: double (nullable = true)
#  |-- c: string (nullable = true)
#  |-- d: date (nullable = true)
#  |-- e: timestamp (nullable = true)

# %%
df.show()
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.show()
#
# File c:\Users\Jakub.Cajzl\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyspark\sql\dataframe.py:945, in DataFrame.show(self, n, truncate, vertical)
#     885 def show(self, n: int = 20, truncate: Union[bool, int] = True, vertical: bool = False) -> None:
#     886     """Prints the first ``n`` rows to the console.
#     887
#     888     .. versionadded:: 1.3.0
#    (...)
#     943     name | Bob
#     944     """
# --> 945     print(self._show_string(n, truncate, vertical))
#
# File c:\Users\Jakub.Cajzl\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyspark\sql\dataframe.py:963, in DataFrame._show_string(self, n, truncate, vertical)
#     957     raise PySparkTypeError(
#     958         error_class="NOT_BOOL",
# ...

# %% [markdown]
# #### Viewing data as Python DataFrame (eager evaluation)

# %%
spark.conf.set('spark.sql.repl.eagerEval.enabled', True)
df
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File c:\Users\Jakub.Cajzl\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyspark\sql\dataframe.py:997, in DataFrame._repr_html_(self)
#     995     self._support_repr_html = True
#     996 if self.sparkSession._jconf.isReplEagerEvalEnabled():
# --> 997     return self._jdf.htmlString(
#     998         self.sparkSession._jconf.replEagerEvalMaxNumRows(),
#     999         self.sparkSession._jconf.replEagerEvalTruncate(),
#    1000     )
#    1001 else:
#    1002     return None
#
# ...

# %% [markdown]
# ## Transformations

# %% [markdown]
# **Transformations:**
# - map(func)
# - filter(func)
# - flatMap(func)
# - mapPartitons(func)
# - sample(withReplacement, fraction, seed)
# - union(otherRDD)
# - intersection(otherRDD)
# - distinct()
# - groupByKey()
# - reduceByKey(func)
# - sortByKey()
# - join(otherRDD)
# - ...

# %% [markdown]
# ## Actions

# %% [markdown]
# **Actions:**
# - reduce(func)
# - count()
# - first()
# - take(n)
# - takeSample(withReplacement, n)
# - saveAsTextFile(path)
# - countByKey()
# - foreach(func)

# %%
# Grouping, counting and sorting:
display(spark_df.groupby("column").count().orderBy("count", ascending=False))

# Or alternatively (Pandas syntax):
spark_df["column"].value_counts()

# %% [markdown]
# ## Pandas on PySpark

# %%
# Example of CSV file read:
df = ps.read_csv(f'{directory}/dataset.csv', inferSchema=True, multiLine=True, escape='"')

# %%
# Converting a Pandas DataFrame to Spark DataFrame:

# First way:
df = ps.DataFrame(spark_DataFrame)
display(df)

# Second way:
df = spark_DataFrame.to_pandas_on_spark()
display(df)

# %% [markdown]
# Note: If a pandas-on-Spark DataFrame is converted to a Spark DataFrame and then back to pandas-on-Spark, it will **lose the index** information and the **original index** will be **converted into** a normal **column**.

# %% [markdown]
# ### SQL on Pandas

# %%
ps.sql("SELECT distinct(column) FROM {spark_DataFrame}")
