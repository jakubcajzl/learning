# %% [markdown]
# # Project 01: **LinkedIn Jobs**

# %% [markdown]
# [Kaggle dataset of scraped LinkedIn jobs](https://www.kaggle.com/datasets/arshkon/linkedin-job-postings/)

# %% [markdown]
# ## To do list:
#
# - celé přepsat do **.py skriptu** (main) - **DONE**
# - write into #logger that it will log max. 1000 rows. - **DONE**
# - extract state names from 'location' column - **DONE**
# - recalculate salaries (min, med, max) according to pay_period - **DONE**
# - extract domain name from 'application_url' and 'posting_domain' -
# - try Logging of the class Errors - **DONE**
# - change searching by title using ALL title keywords, not only the exact match - maybe write different functions for 'exact match' or 'partial match' - **DONE**
# - change the class interaction using **input method** - The client would be asked e.g. location, job title, etc. and the result would be job applications -
# - create a method for filtering jobs by multiple conditions at the same time, e.g. job title and location, etc. -

# %% [markdown]
# ## Setting-up an environment:

# %%
# Importing main libraries:
import datetime
import logging
import yaml
import pandas as pd
import numpy as np
from itertools import chain

# Statistics and EDA libraries:
import scipy as stats
import sweetviz as sv
from ydata_profiling import ProfileReport  # former pandas_profiling!

# Plotting libraries:
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Setting-up the display options for Pandas dataframes to display all the columns (not truncated):
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# Creating a class for different print styles:
class style:
    #-------------------
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    BLUE = '\033[94m'
    GREEN = '\033[92m'
    RED = '\033[91m'
    #-------------------
    YELLOW = '\033[93m'
    PURPLE = '\033[95m'
    CYAN = '\033[96m'
    DARKCYAN = '\033[36m'
    #-------------------
    END = '\033[0m'
    #-------------------

# %%
### FUNCTIONS ###

# =================================================================================================================== #
def get_dataframe_name(dataframe: pd.DataFrame) -> str:
    """
    The function returns a name of the DataFrame variable as a string.
    
    Parameters: 
    - dataframe (pd.DataFrame): DataFrame variable
    
    Returns: 
    - str: name of the DataFrame variable as a string
    """
    
    for obj_name, obj in globals().items():
        if obj is dataframe and isinstance(obj, pd.DataFrame):
            return obj_name
# =================================================================================================================== #


# =================================================================================================================== #
# Function for loading the file:
def csv_load(file: str, delimiter: str) -> pd.DataFrame:
    """
    The function loads the files in the CSV format (with specified delimiter) into Pandas dataframe.
    
    Parameters:
    - file (string): the whole path of the CSV file (including a file name with file extension), e.g.: '../dataset/job_postings.csv'
    - delimiter (str): the delimiter used in the CSV, e.g.: comma, semicolon, etc.
    
    Return:
    - pd.Dataframe: the dataframe that holds the data from the CSV file
    """
    
    try:
        print(f'Loading the {file} file using a delimiter: {delimiter}')
        pd.read_csv(file, delimiter=delimiter)
        print(f'File was succesfully loaded into the dataframe using a delimiter: {delimiter}')
    except Exception as error:
        print(f'Error: {error}')
        print('File was not loaded into the dataframe!')
    else:
        return pd.read_csv(file, delimiter=delimiter)
# =================================================================================================================== #


# =================================================================================================================== #
def flatten_list(cell_list):
    """
    The function flattens a list structure.
    
    Parameters:
    - cell_list (string): a list to flatten
    
    Return:
    - list: a list with flattened structure
    """
    
    return list(chain.from_iterable(cell_list))
# =================================================================================================================== #

# %% [markdown]
# ## Importing final CSV file

# %%
# Final dataset:
# Reading the CSV file into a Pandas DataFrame:
file = 'final_dataset.csv'
data = csv_load(file, ',')
display(data.loc[0:3])
# Out:
# Loading the final_dataset.csv file using a delimiter: ,
# File was succesfully loaded into the dataframe using a delimiter: ,
#        job_id  company_id                                              title  \
# 0  3757940104    553718.0                              Hearing Care Provider
# 1  3757940025   2192142.0  Shipping & Receiving Associate 2nd shift (Beav...
# 2  3757938019    474443.0                               Manager, Engineering
# 3  3757938018  18213359.0                                               Cook
#
#                                          description  work_type  \
# 0  Overview\n\nHearingLife is a national hearing ...  Full-time
# 1  Metalcraft of Mayville\nMetalcraft of Mayville...  Full-time
# 2  \nThe TSUBAKI name is synonymous with excellen...  Full-time
# 3  descriptionTitle\n\n Looking for a great oppor...  Full-time
#
#            location  applies  original_listed_time  remote_allowed  views  \
# 0  Little River, SC      NaN          1.699090e+12             NaN    9.0
# 1    Beaver Dam, WI      NaN          1.699080e+12             NaN    NaN
# 2      Bessemer, AL      NaN          1.699080e+12             NaN    NaN
# 3   Aliso Viejo, CA      NaN          1.699080e+12             NaN    1.0
#
#                                      job_posting_url  \
# 0  https://www.linkedin.com/jobs/view/3757940104/...
# 1  https://www.linkedin.com/jobs/view/3757940025/...
# 2  https://www.linkedin.com/jobs/view/3757938019/...
# 3  https://www.linkedin.com/jobs/view/3757938018/...
#
#                                      application_url application_type  \
# 0  https://careers-demant.icims.com/jobs/19601/he...     OffsiteApply
# 1  https://www.click2apply.net/mXLQz5S5NEYEXsKjwH...     OffsiteApply
# 2  https://www.click2apply.net/LwbOykH2yAJdahB5Ah...     OffsiteApply
# 3  https://jobs.apploi.com/view/854782?utm_campai...     OffsiteApply
#
#     expiry_time  closed_time experience_level  \
# 0  1.701680e+12          NaN      Entry level
# 1  1.701680e+12          NaN              NaN
# 2  1.701680e+12          NaN              NaN
# 3  1.701680e+12          NaN      Entry level
#
#                                          skills_desc   listed_time  \
# 0                                                NaN  1.699090e+12
# 1                                                NaN  1.699080e+12
# 2  Bachelor's Degree in Mechanical Engineering pr...  1.699080e+12
# 3                                                NaN  1.699080e+12
#
#              posting_domain  sponsored     scraped  \
# 0  careers-demant.icims.com          0  1699138101
# 1       www.click2apply.net          0  1699085420
# 2       www.click2apply.net          0  1699085644
# 3           jobs.apploi.com          0  1699087461
#
#                            company_name  \
# 0                           HearingLife
# 1          Metalcraft of Mayville, Inc.
# 2  U.S. Tsubaki Power Transmission, LLC
# 3      Episcopal Communities & Services
#
#                                          company_url  \
# 0      https://www.linkedin.com/company/hearing-life
# 1  https://www.linkedin.com/company/metalcraft-of...
# 2  https://www.linkedin.com/company/u.s.-tsubaki-...
# 3  https://www.linkedin.com/company/episcopal-com...
#
#                                             industry  salary_id  max_salary  \
# 0                                         ['Retail']    13493.0         NaN
# 1             ['Industrial Machinery Manufacturing']        NaN         NaN
# 2             ['Automation Machinery Manufacturing']        NaN         NaN
# 3  ['Non-profit Organization Management', 'Non-pr...    12025.0         NaN
#
#    med_salary  min_salary pay_period currency compensation_type  \
# 0     5250.00         NaN    MONTHLY      USD       BASE_SALARY
# 1         NaN         NaN        NaN      NaN               NaN
# 2         NaN         NaN        NaN      NaN               NaN
# 3       22.27         NaN     HOURLY      USD       BASE_SALARY
#
#   employee_count follower_count       skills_abbr  \
# 0         [1171]        [11417]          ['OTHR']
# 1          [300]         [2923]  ['MGMT', 'MNFC']
# 2          [314]         [8487]           ['ENG']
# 3           [36]          [305]  ['MGMT', 'MNFC']
#
#                             skills original_listed_time_ms  \
# 0                        ['Other']     2023-11-04 09:26:40
# 1  ['Management', 'Manufacturing']     2023-11-04 06:40:00
# 2                  ['Engineering']     2023-11-04 06:40:00
# 3  ['Management', 'Manufacturing']     2023-11-04 06:40:00
#
#         expiry_time_ms closed_time_ms       listed_time_ms           state  \
# 0  2023-12-04 08:53:20            NaN  2023-11-04 09:26:40  South carolina
# 1  2023-12-04 08:53:20            NaN  2023-11-04 06:40:00       Wisconsin
# 2  2023-12-04 08:53:20            NaN  2023-11-04 06:40:00         Alabama
# 3  2023-12-04 08:53:20            NaN  2023-11-04 06:40:00      California
#
#   state_abbr  min_salary_normalized  med_salary_normalized  \
# 0         SC                    NaN                63000.0
# 1         WI                    NaN                    NaN
# 2         AL                    NaN                    NaN
# 3         CA                    NaN                46321.6
#
#    max_salary_normalized
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN

# %% [markdown]
# ## Use Case - Searching for jobs:

# %% [markdown]
# Possible other search conditions:
# - remote
# - views
# - posting_domain
# - listing_time
# - linkedin_url
# - application_url

# %%
###  VERSION 04 (Chaining filters)  ###
# Defining a class for finding jobs according to specific properties:

class JobFinder:
    '''
    A class for finding jobs according to specific properties.
    
    NOTE: Inthe end of each search query needs to be '.get_data()' method 
    in order to retrieve the final filtered data.
    Example: jobs = job_finder.location("California").salary_range(60000, 80000).get_data()
    '''
    
    def __init__(self, jobs):
        self.jobs = jobs
    
    def title(self, title):
        filtered_jobs = self.jobs[ self.jobs['title'].astype(str).str.contains(title, case=False, regex=True) ]
        return JobFinder(filtered_jobs)
    
    def company_name(self, company_name):
        filtered_jobs = self.jobs[ self.jobs['company_name'].astype(str).str.contains(company_name, case=False, regex=True) ]
        return JobFinder(filtered_jobs)
    
    def description(self, description):
        filtered_jobs = self.jobs[ self.jobs['description'].astype(str).str.contains(description, case=False, regex=True) ]
        return JobFinder(filtered_jobs)
    
    def location(self, location):
        filtered_jobs = self.jobs[
            (self.jobs['state'].astype(str).str.lower() == location.lower()) |
            (self.jobs['state'].isna()) |
            (self.jobs['state_abbr'].astype(str).str.lower() == location.lower()) |
            (self.jobs['state_abbr'].isna())
        ]
        return JobFinder(filtered_jobs)
    
    def experience_level(self, experience_level):
        filtered_jobs = self.jobs[ self.jobs['experience_level'].apply(flatten_list).astype(str).str.contains(experience_level, case=False, regex=True) ]
        return JobFinder(filtered_jobs)
    
    def skills(self, skills):
        filtered_jobs = self.jobs[ self.jobs['skills'].astype(str).str.contains(skills, case=False, regex=True) ]
        return JobFinder(filtered_jobs)
    
    def work_type(self, work_type):
        filtered_jobs = self.jobs[ self.jobs['work_type'].astype(str).str.contains(work_type, case=False, regex=True) ]
        return JobFinder(filtered_jobs)
    
    def salary_range(self, min_salary, max_salary):
        filtered_jobs = self.jobs[
            (((self.jobs['min_salary_normalized'] >= min_salary) | self.jobs['min_salary_normalized'].isna()) & 
             ((self.jobs['max_salary_normalized'] <= max_salary) | self.jobs['max_salary_normalized'].isna())) | 
            (((self.jobs['med_salary_normalized'] >= min_salary) | self.jobs['med_salary_normalized'].isna()) & 
             ((self.jobs['med_salary_normalized'] <= max_salary) | self.jobs['med_salary_normalized'].isna()))
        ]
        return JobFinder(filtered_jobs)
    
    def salary_range_simple(self, min_salary, max_salary):
        filtered_jobs = self.jobs[ (self.jobs['min_salary_normalized'] >= min_salary) & (self.jobs['max_salary_normalized'] <= max_salary)  ]
        return JobFinder(filtered_jobs)
    
    def salary_range_median(self, min_salary, max_salary):
        filtered_jobs = self.jobs[ (self.jobs['med_salary_normalized'] >= min_salary) & (self.jobs['med_salary_normalized'] <= max_salary)  ]
        return JobFinder(filtered_jobs)
    
    
    # Function to retrieve the filtered data:
    def get_data(self):
        return self.jobs

# Creating an instance of the JobFinder class with data DataFrame:
job_finder = JobFinder(data)

# %%
# USE case: Filtering jobs by many conditions:
filtered_jobs = job_finder.description('python').location('California').salary_range(60000, 80000).skills('information').work_type('full-time').get_data()
print('Number of matches:', len(filtered_jobs))
filtered_jobs.iloc[0:5]
# Out:
# Number of matches: 303
#          job_id  company_id                                    title  \
# 15   3757935012  18583501.0               Quantitative Trader [5048]
# 153  3757922135   2957445.0                       Fullstack Engineer
# 170  3757920617  54350022.0  Full Stack Developer - API Integrations
# 198  3757918639         NaN                          Staff Scientist
# 224  3757917592     10091.0         Principal VMware Cloud Architect
#
#                                            description  work_type  \
# 15   Quantitative traders research, develop, and re...  Full-time
# 153  About FareHarbor\n\nAt FareHarbor, our mission...  Full-time
# 170  Full Stack Developer - API IntegrationsJob Des...  Full-time
# 198  \nResponsibilitiesLooking for a Staff Scientis...  Full-time
# 224  Company Summary Statement\n\nAs one of the lar...  Full-time
#
#                     location  applies  original_listed_time  remote_allowed  \
# 15   New York, United States     36.0          1.699080e+12             NaN
# 153        San Francisco, CA     16.0          1.696920e+12             NaN
# 170            United States      4.0          1.699080e+12             1.0
# 198             San Jose, CA      NaN          1.699080e+12             NaN
# 224            United States      1.0          1.696920e+12             1.0
#
#      views                                    job_posting_url  \
# 15   158.0  https://www.linkedin.com/jobs/view/3757935012/...
# 153   40.0  https://www.linkedin.com/jobs/view/3757922135/...
# 170    6.0  https://www.linkedin.com/jobs/view/3757920617/...
# 198   23.0  https://www.linkedin.com/jobs/view/3757918639/...
# 224    5.0  https://www.linkedin.com/jobs/view/3757917592/...
#
#                                        application_url    application_type  \
# 15                                                 NaN  ComplexOnsiteApply
# 153  https://fareharbor.com/careers/jobs/?gh_jid=68...        OffsiteApply
# 170                                                NaN   SimpleOnsiteApply
# 198                                                NaN  ComplexOnsiteApply
# 224   https://careers.pplweb.com/jobs/10012?lang=en-us        OffsiteApply
#
#       expiry_time  closed_time  experience_level skills_desc   listed_time  \
# 15   1.701670e+12          NaN         Associate         NaN  1.699080e+12
# 153  1.701670e+12          NaN       Entry level         NaN  1.699080e+12
# 170  1.701670e+12          NaN               NaN         NaN  1.699080e+12
# 198  1.701670e+12          NaN               NaN         NaN  1.699080e+12
# 224  1.701670e+12          NaN  Mid-Senior level         NaN  1.699080e+12
#
#          posting_domain  sponsored     scraped         company_name  \
# 15                  NaN          0  1699135011      Stealth Startup
# 153      fareharbor.com          0  1699081419           FareHarbor
# 170                 NaN          0  1699080309  Jobsrefer Indonesia
# 198                 NaN          0  1699132529                  NaN
# 224  careers.pplweb.com          0  1699085346      PPL Corporation
#
#                                            company_url  \
# 15   https://www.linkedin.com/company/stealth-start...
# 153        https://www.linkedin.com/company/fareharbor
# 170  https://www.linkedin.com/company/jobsrefer-ind...
# 198                                                NaN
# 224    https://www.linkedin.com/company/pplcorporation
#
#                          industry  salary_id  max_salary  med_salary  \
# 15       ['Software Development']        NaN         NaN         NaN
# 153       ['Travel Arrangements']    11223.0    160610.0         NaN
# 170  ['Human Resources Services']        NaN         NaN         NaN
# 198                           NaN    12779.0    155000.0         NaN
# 224                 ['Utilities']        NaN         NaN         NaN
#
#      min_salary pay_period currency compensation_type         employee_count  \
# 15          NaN        NaN      NaN               NaN  [16720, 16721, 16736]
# 153    144591.0     YEARLY      USD       BASE_SALARY                  [737]
# 170         NaN        NaN      NaN               NaN                    [7]
# 198    145000.0     YEARLY      USD       BASE_SALARY                    NaN
# 224         NaN        NaN      NaN               NaN           [6098, 6120]
#
#                follower_count             skills_abbr  \
# 15   [572517, 572617, 573230]                  ['IT']
# 153                   [12893]           ['ENG', 'IT']
# 170                   [18020]           ['ENG', 'IT']
# 198                       NaN  ['RSCH', 'ANLS', 'IT']
# 224            [37777, 37456]           ['ENG', 'IT']
#
#                                                 skills  \
# 15                          ['Information Technology']
# 153          ['Engineering', 'Information Technology']
# 170          ['Engineering', 'Information Technology']
# 198  ['Research', 'Analyst', 'Information Technology']
# 224          ['Engineering', 'Information Technology']
#
#     original_listed_time_ms       expiry_time_ms closed_time_ms  \
# 15      2023-11-04 06:40:00  2023-12-04 06:06:40            NaN
# 153     2023-10-10 06:40:00  2023-12-04 06:06:40            NaN
# 170     2023-11-04 06:40:00  2023-12-04 06:06:40            NaN
# 198     2023-11-04 06:40:00  2023-12-04 06:06:40            NaN
# 224     2023-10-10 06:40:00  2023-12-04 06:06:40            NaN
#
#           listed_time_ms       state state_abbr  min_salary_normalized  \
# 15   2023-11-04 06:40:00         NaN        NaN                    NaN
# 153  2023-11-04 06:40:00  California         CA               144591.0
# 170  2023-11-04 06:40:00         NaN        NaN                    NaN
# 198  2023-11-04 06:40:00  California         CA               145000.0
# 224  2023-11-04 06:40:00         NaN        NaN                    NaN
#
#      med_salary_normalized  max_salary_normalized
# 15                     NaN                    NaN
# 153                    NaN               160610.0
# 170                    NaN                    NaN
# 198                    NaN               155000.0
# 224                    NaN                    NaN
